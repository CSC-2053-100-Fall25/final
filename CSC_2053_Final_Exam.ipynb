# %% [markdown]
# <a href="https://colab.research.google.com/github/CSC-2053-100-Fall25/final/blob/main/CSC_2053_Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to the CSC 2053 Final Exam - Part Two!
#
# It's recommended you run one cell at a time.  You may use anything on the internet to help you answer the questions.  Please include the name of the source.  You do not need to specifically include a link.
#
# However you solve these functions is fine. There are many approaches to the same result in Python and I will not be particular.
#
# # At the end of the exam, download the completed notebook as a .ipynb file.
#
# • Click File > Download > Download .ipynb.
# Then, upload the file to your GitHub Repo.  Make sure the file uploads, and that is all you have to do; you are good to go.

# %% [markdown]
# # FIRST - Import your Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Change the variable below to enter your name and ensure that all Python libraries are available for you to use. You will lose points if you do not enter your name. If you encounter any trouble, please let the instructor know!

# %%
#@title Enter Your Name
student_name = "Your Name Here" #@param {type:"string"}

print(f"Student Name: {student_name}")

# %% [markdown]
# # Task One - Spread Some Holiday Cheer!
#
# Write a function called christmas_cheer that takes a list of radio station call signs (e.g., ["WNJL", "WXVU", "WXYC"]) and returns a list of holiday greetings for each station. Each greeting should be in the format:
#
# "Merry Christmas from {station}!"
#
# **Note that the greetings need to be in a LIST ([])**
#
# If your function is working, when you run the cell below, all you should see is:
#
# *Task 1 - Test 1 - Correct - Ho Ho Ho*

# %%
def christmas_cheer(stations):
    """
    Takes a list of radio station call signs and returns a list of holiday cheers for each station.
    """
    return

# Test cases for the function
result = christmas_cheer(["WNJL", "WXVU", "WXYC"])
assert result == [
    "Merry Christmas from WNJL!",
    "Merry Christmas from WXVU!",
    "Merry Christmas from WXYC!",
], "Test failed: Cheers not in expected format"
print("Task 1 - Test 1 - Ho Ho Ho")

# %% [markdown]
# # Task Two - Michigan Radio Analysis
#
# Similar to our lab and homework in class, the task here is to import the Michigan FM radio station dataset that is provided for you online.
#
# There are eight questions total here.
#
# Most questions require you to provide code for your answers and simply print the results. There are no tests to run.
#
# Some questions provide code that you simply need to run to generate plots.
#
# For your reference, the names of the columns in the dataset are as follows:
#
# 	1.	frequency
# 	2.	callsign
# 	3.	city
# 	4.	state
# 	5.	power
# 	6.	lat
# 	7.	lon
# 	8.	height
# 	9.	slogan
# 	10.	owner
# 	11.	format
# 	12.	mlb
# 	13.	nfl
# 	14.	nba
# 	15.	nhl
# 	16.	market
# 	17.	rank
# 	18.	npr

# %% [markdown]
# *First, ensure the data is imported*

# %%
# Replace with the raw URL of your CSV file
url = "https://raw.githubusercontent.com/CSC-2053-100-Fall25/final/main/fm_MI.csv"

# Load the CSV into a DataFrame
df = pd.read_csv(url)

# Convert longitude to negative (Michigan is in Western Hemisphere)
df['lon'] = df['lon'] * -1

# Display the first few rows of the DataFrame
print(df.head(3))

# %% [markdown]
#  1. **In the cell below, print the stations in the dataframe, df, with the 10 highest power values, sorted greatest to least. Print only the frequency, callsign, city, and power columns. If correct, your result should start with:**
#
#
#
# > 93.7	WBCT	GRAND RAPIDS
#
# > 105.7	WSRW-FM	GRAND RAPIDS

# %%
### Insert your code for the highest power values here ###

# %% [markdown]
#  2. **In the cell below, print the value counts of the format column in the Michigan dataset.  If successful, your output should start with:**
#
#
#
#
#
# > Country	91

# %%
### Insert your code for the value counts of the formats here ###

# %% [markdown]
#  3. **In the cell below, print the value counts of the owner column in the Michigan dataset. Show only the top 10 owners.
#
#  Make sure to name your variable **mi_owner_counts**, as it will impact whether or not your graph appears in question 5.
#
#
#    If successful, your output should start with:**
#
#
#
#
#
# > iHeartMedia	36

# %%
### Insert your code for the value counts of the owners here ###

# %% [markdown]
#  4. **The code below will create a scatter plot showing Michigan FM radio stations by their latitude and longitude. Simply run the cell to generate the plot.**

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['lon'], df['lat'], alpha=0.5, c='blue', s=30)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Michigan FM Radio Stations by Location')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
#  5. **The code below will create a bar chart showing the top 10 radio station owners in Michigan. If you correctly completed question 3 above and stored your result in mi_owner_counts, this cell will work. Simply run it to generate the chart.**

# %%
plt.figure(figsize=(10, 6))
mi_owner_counts.plot(kind='bar')
plt.title('Top 10 Radio Station Owners in Michigan')
plt.xlabel('Owner')
plt.ylabel('Number of Stations')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
#  6. **In the cell below, find and print the number of FM radio stations licensed to the city of Traverse City. If correct, your answer should be:**
#
#
#
#
#
# > 10

# %%
### Insert your code to count Traverse City stations here ###

# %% [markdown]
#  7. **In the cell below, find and print the number of FM radio stations in Michigan that broadcast Detroit Lions games. Look at the nfl column and count stations where nfl == 'Lions'. If correct, your answer should be:**
#
#
#
#
#
# > 34

# %%
### Insert your code to count Lions broadcast stations here ###

# %% [markdown]
#  8. **In the cell below, find the farthest north FM radio station in Michigan by finding the station with the highest latitude value. Print the callsign, city, and latitude. If correct, your result should be:**
#
#
#
#
#
# > WDRK	Laurium	47.25361111111111

# %%
### Insert your code to find the farthest north station here ###

# %% [markdown]
# # End of exam!
#
# To submit your final:
#
# **Click File > Download > Download .ipynb.**
# Then, upload the file to your GitHub Repo that GitHub Classroom created.  Make sure the file uploads, and that is all you have to do; you are good to go.
